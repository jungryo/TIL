# %%
import os
import sys
import urllib.request
client_id = "U6Nwa4R5btkJChk_o1qS"
client_secret = "7WgX2pcmll"
encText = urllib.parse.quote("데이터사이언티스트")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)

# %%
response.getcode()
# Out:
# 200

# %%
encText = urllib.parse.quote("데이터사이언티스트")
url = "https://openapi.naver.com/v1/search/book?query=" + encText
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
print(response.read().decode('utf-8'))
# Out:
# {
# "lastBuildDate": "Tue, 27 Oct 2020 20:31:52 +0900",
# "total": 62,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "문과생, <b>데이터 사이언티스트</b> 되다 (<b>데이터</b>를 비즈니스에 활용하고 싶은 이들을 위한 가장 쉬운 안내서)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16368080",
# "image": "https://bookthumb-phinf.pstatic.net/cover/163/680/16368080.jpg?type=m1&udate=20200814",
# "author": "차현나",
# "price": "15000",
# "discount": "13500",
# "publisher": "더퀘스트",
# "pubdate": "20200601",
# "isbn": "116521153X 9791165211530",
# "description": "“코딩 배우기 전 데이터의 쓸모부터 판단하라”\n기술이 발달할수록 오히려 중요해지는 것은\n데이터를 분석하고 해석하는 인문학적인 능력이다스타벅스코리아 1호 <b>데이터 사이언티스트</b>의 \n넘쳐나는 숫자 속에서 기업과 소비자가 원하는 ‘가치’를 찾아내는 방법\n\n● 데이터를 활용해 마케팅의 성과를 높이고... "
#
# },
# {
# "title": "<b>데이터 사이언티스트</b> (빅<b>데이터</b> 시대를 살아가는 사람들의 이야기,가장 섹시한 직업)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14650211",
# "image": "https://bookthumb-phinf.pstatic.net/cover/146/502/14650211.jpg?type=m1&udate=20190830",
# "author": "김진호",
# "price": "15000",
# "discount": "13500",
# "publisher": "북카라반",
# "pubdate": "20190329",
# "isbn": "1160050627 9791160050622",
# "description": "“<b>데이터</b>는 세상을 들여다보는 창(窓)이다.”\n- 한스 로슬링(Hans Rosling, 스웨덴 통계학자)\n\n“앞으로 모든 산업에서 <b>데이터</b>가 승자와 패자를 가를 것이다.”\n- 버지니아 로메티(Virginia Rometty, IBM CEO)\n\n“인간이 1초 만에 인지할 수 있는 것들은 이제 대부분 자동화될 수 있다.”\n- 앤드루... "
#
# },
# {
# "title": "<b>데이터 사이언티스트</b> 어떻게 되었을까? (현직 <b>데이터 사이언티스트</b>들을 통해 알아보는 리얼 직업 이야기)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16300104",
# "image": "https://bookthumb-phinf.pstatic.net/cover/163/001/16300104.jpg?type=m1&udate=20200403",
# "author": "원인재",
# "price": "15000",
# "discount": "13500",
# "publisher": "캠퍼스멘토",
# "pubdate": "20200228",
# "isbn": "8997826352 9788997826353",
# "description": "“대한민국 각 분야 최고의 <b>데이터 사이언티스트</b>들이 청소년의 관점으로 \n자신이 걸어온 길을 이야기해 준다.”『<b>데이터 사이언티스트</b> 어떻게 되었을까?』는 엄마 아빠도 모르고 선생님도 몰랐던, <b>데이터 사이언티스트</b> 5인이 말하는 진짜 <b>데이터 사이언티스트</b> 이야기를 담은 책이다. 고영혁, 김영호, 김유경... "
#
# },
# {
# "title": "마케터가 알려주는 돈이 되는 빅<b>데이터</b> 분석 (실전에서 바로 써먹는 빅<b>데이터</b> 마케팅 노하우)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16490700",
# "image": "https://bookthumb-phinf.pstatic.net/cover/164/907/16490700.jpg?type=m1&udate=20200805",
# "author": "강지은",
# "price": "15000",
# "discount": "13500",
# "publisher": "렛츠북",
# "pubdate": "20200805",
# "isbn": "1160543836 9791160543834",
# "description": "데이터 웨어하우스의 분석 툴을 이용하여 데이터를 뽑는 사람을 일컬어 ‘<b>데이터 사이언티스트</b>’라고 한다. 하지만 단순히 데이터를 뽑는 일뿐만 아니라 분석한 데이터를 마케팅에 활용하는 역할도 하기에 ‘<b>데이터 사이언티스트</b>’보다는 ‘마케팅 사이언티스트’라는 단어로 정의되어야 한다고 생각한다.... "
#
# },
# {
# "title": "브라이틱스와 함께하는 <b>데이터</b> 분석",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16408093",
# "image": "https://bookthumb-phinf.pstatic.net/cover/164/080/16408093.jpg?type=m1&udate=20200711",
# "author": "박현경|고락윤|이지현|서범준|이영선",
# "price": "39000",
# "discount": "35100",
# "publisher": "하우",
# "pubdate": "20200709",
# "isbn": "1190154536 9791190154536",
# "description": "- <b>데이터</b> 분석의 모든 것을 브라이틱스를 통해?배울 수 있는 최고의 지침서\n- 다양한 <b>데이터</b>분석 방법론을 배울 수 있는 최고의 지침서\n- PRODS 실기평가... 원활하게 <b>데이터</b> 분석을 할 수 있게 해 준다는 데 가장 큰 장점이 있습니다. 무엇보다 그 어떤 툴과 비교해도 사용자 친화적으로 분석 진행 과정의 흐름을... "
#
# },
# {
# "title": "<b>데이터</b>사이언스 입문 (인공지능시대의 전문서)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16293609",
# "image": "https://bookthumb-phinf.pstatic.net/cover/162/936/16293609.jpg?type=m1&udate=20200319",
# "author": "일본 국립 시가대학교 <b>데이터</b>사이언스학부 타케무라 ?",
# "price": "22000",
# "discount": "20900",
# "publisher": "인피니티북스",
# "pubdate": "20200312",
# "isbn": "1185578579 9791185578576",
# "description": "손에 잡히는 설명, 쉽게 풀어가는 <b>데이터</b>사이언스이 책은 빅 <b>데이터</b> 시대를 살아가는 독자들이 습득해야 하는 필독서로서 <b>데이터</b>사이언스 분야에 대한 개론 내용을 함축하여 해설하고, 보다 고급수준의 내용을 학습하기 위한 가교역할을 하는 교과서이다. 또한 대학의 교양과정에서 활용하는 것을 생각한다면... "
#
# },
# {
# "title": "빅<b>데이터</b>, 인공지능을 만나다",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16349877",
# "image": "https://bookthumb-phinf.pstatic.net/cover/163/498/16349877.jpg?type=m1&udate=20200512",
# "author": "심준식|우재현",
# "price": "19000",
# "discount": "17100",
# "publisher": "한국금융연수원",
# "pubdate": "20200429",
# "isbn": "8928726018 9788928726011",
# "description": "또한 회사에서 빅데이터 플랫폼을 이용한 빅데이터 분석을 통해 회사에 도움이 되는 인사이트를 도출하기 위해서는 빅데이터 분석을 담당하는 <b>데이터사이언티스트</b> 뿐만 아니라 회사의 어떤 과제를 빅데이터 분석의 주제로 정할지를 기획하는 업무 지식이 가진 빅데이터 기획담당자의 역할이 중요하다. 그리고... "
#
# },
# {
# "title": "<b>데이터</b> 분석 전문가,준전문가 단기완성 (2019)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14573436",
# "image": "https://bookthumb-phinf.pstatic.net/cover/145/734/14573436.jpg?type=m1&udate=20190309",
# "author": "김경태",
# "price": "28000",
# "discount": "25200",
# "publisher": "시대고시기획",
# "pubdate": "20190405",
# "isbn": "1125456299 9791125456292",
# "description": "은 한 권으로 자격시험을 충분히 대비하고 준비할 수 있도록 아래와 같이 구성되었습니다.\n\nㆍ 출제 유형을 최대한 반영한 핵심이론을 통해 개념을 확실히 짚고 넘어갈 수 있습니다.\nㆍ 핵심이론 학습 이후에는 과목별 적중예상문제를 통해 변동된 출제 기준을 확실히 기억할 수 있습니다.\nㆍ 기출 유형을 충실히... "
#
# },
# {
# "title": "빅<b>데이터</b> 전쟁 (글로벌 빅<b>데이터</b> 경쟁에서 살아남는 법)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=9521399",
# "image": "https://bookthumb-phinf.pstatic.net/cover/095/213/09521399.jpg?type=m1&udate=20190202",
# "author": "박형준",
# "price": "13800",
# "discount": "12420",
# "publisher": "세종서적",
# "pubdate": "20150831",
# "isbn": "8984075116 9788984075115",
# "description": "『빅<b>데이터</b> 전쟁』은 <b>데이터</b> 분석이 실패하는 원인을 집중적으로 다루고 있다. 막연한 <b>데이터</b> 분석 무용론을 떠나, 논리적이고 객관적으로 현상을 분석하고 근본 원인을 찾는다. 그런 다음 어떻게 해야 글로벌 빅<b>데이터</b> 경쟁에서 승리하고 살아남을 수 있는지에 대해 실제 기업의 사례를 들어 자세히 설명한다."
#
# },
# {
# "title": "빅<b>데이터</b>를 활용한 통계분석 (빅<b>데이터</b>를 활용한 인공지능 개발 1)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15202970",
# "image": "https://bookthumb-phinf.pstatic.net/cover/152/029/15202970.jpg?type=m1&udate=20190719",
# "author": "송주영|송태민",
# "price": "15000",
# "discount": "13500",
# "publisher": "황소걸음아카데미",
# "pubdate": "20190720",
# "isbn": "1186821388 9791186821381",
# "description": "이에 따라 방대한 데이터를 수집·관리하면서 복잡하고 다양한 사회현상을 분석할 수 있는 능력을 지닌 <b>데이터 사이언티스트</b>의 역할은 그 중요성이 더해가고 있다.\n\n그동안 우리 주변의 사회현상을 예측하기 위해 모집단을 대표할 수 있는 표본을 추출하여 표본에서 생산된 통계량으로 모집단의 모수를 추정해... "
#
# }
# ]
# }
